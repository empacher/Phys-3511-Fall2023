# %%
#problem 1
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

def sa(x):
    return (x - 1) * np.log(x) - x + 0.5 * np.log(2 * np.pi * x)

x = np.linspace(2, 100)
y2 = np.log(x)

x = np.linspace(2, 100)
y1 = sa(x)

plt.figure(figsize=(8, 6))  
plt.plot(x, y2, label='ln(x)') 
plt.plot(x, y1, label = 'stirlings approximation')
plt.xlabel('n')  
plt.legend() 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
#problem 2
import numpy as np

seven = np.ones(100)*7

# %%
#problem 3
import numpy as np

np.random.seed(0)
arr = np.random.randint(0,11,50)
print(arr[arr>5])
# Out:
# [ 7  9  7  6  8  8 10  6  7  7  8  9  8  9  8  7  9  9 10  7  7]

# %%
#problem 4
import numpy as np

np.random.seed(0)
arr2 = np.random.randint(0, 6, 20)
new = arr2[arr2 != 3]
print(new)
# Out:
# [4 5 0 1 5 2 4 0 0 4 2 1 0 1 5 1]

# %%
#problem 5 part a and b
import numpy as np
import matplotlib.pyplot as plt

rows, cols = 1000, 1000 #makes matrix
matrix = np.random.randn(rows, cols) 
print(matrix.shape)

fig, axes = plt.subplots(1, 3, figsize=(12, 6)) #to makw the subplots

axes[0].hist(matrix[0, :], bins =30) #histogram 1
axes[0].set_xlabel('x random values')

axes[1].hist(matrix[1, :], bins=30) #histogram 2
axes[1].set_xlabel('y random values')

x = matrix[0, :]
y = matrix[1, :]
hist2d, xedge, yedge = (np.histogram2d)(x, y, bins = 30)

lol = axes[2].imshow(hist2d.T)
axes[2].set_xlabel('heatmap')
plt.colorbar(lol, ax = axes[2])

plt.show()
# Out:
# (1000, 1000)

# %%
#problem 6

import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 1, 100)

y = x ** 3

plt.plot(x, y, color = 'pink')
plt.xlabel('x')
plt.ylabel('y')
plt.title('x^3 vs x')
plt.show()
